# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 750

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_conditions = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description" : city_conditions})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | port elizabeth
# Processing Record 3 of Set 1 | saint george
# Processing Record 4 of Set 1 | okha
# Processing Record 5 of Set 1 | amahai
# Processing Record 6 of Set 1 | saldanha
# Processing Record 7 of Set 1 | huazolotitlan
# City not found. Skipping...
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | port hedland
# Processing Record 10 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 1 | ancud
# Processing Record 12 of Set 1 | longyearbyen
# Processing Record 13 of Set 1 | pitimbu
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 1 | riyadh
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | constitucion
# Processing Record 21 of Set 1 | comodoro rivadavia
# Processing Record 22 of Set 1 | houston
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | gizo
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | liuhe
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | umm lajj
# Processing Record 29 of Set 1 | kavaratti
# Processing Record 30 of Set 1 | meadow lake
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | mogadishu
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | mandurah
# Processing Record 40 of Set 1 | black river
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | polunochnoye
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | puerto carreno
# Processing Record 46 of Set 1 | wanlaweyn
# Processing Record 47 of Set 1 | mana
# Processing Record 48 of Set 1 | kroya
# Processing Record 49 of Set 1 | fevralsk
# City not found. Skipping...
# Processing Record 50 of Set 1 | gazojak
# Processing Record 1 of Set 2 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 2 of Set 2 | caravelas
# Processing Record 3 of Set 2 | tuatapere
# Processing Record 4 of Set 2 | chupa
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | bathsheba
# Processing Record 7 of Set 2 | yar-sale
# Processing Record 8 of Set 2 | tartki
# City not found. Skipping...
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | deputatskiy
# Processing Record 11 of Set 2 | nuuk
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | comacchio
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | kruisfontein
# Processing Record 16 of Set 2 | prince rupert
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | kawalu
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | mazatlan
# Processing Record 22 of Set 2 | luderitz
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | robertsport
# Processing Record 26 of Set 2 | yelovo
# Processing Record 27 of Set 2 | severo-kurilsk
# Processing Record 28 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 2 | geraldton
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | port lincoln
# Processing Record 32 of Set 2 | nanortalik
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | vardo
# Processing Record 35 of Set 2 | williamsport
# Processing Record 36 of Set 2 | saskylakh
# Processing Record 37 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | hamilton
# Processing Record 40 of Set 2 | nagato
# Processing Record 41 of Set 2 | kavieng
# Processing Record 42 of Set 2 | ha tinh
# Processing Record 43 of Set 2 | coquimbo
# Processing Record 44 of Set 2 | bandarbeyla
# Processing Record 45 of Set 2 | the valley
# Processing Record 46 of Set 2 | tilichiki
# Processing Record 47 of Set 2 | maningrida
# Processing Record 48 of Set 2 | preeceville
# Processing Record 49 of Set 2 | burgersdorp
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | port blair
# Processing Record 2 of Set 3 | poronaysk
# Processing Record 3 of Set 3 | sabha
# Processing Record 4 of Set 3 | faya
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | sitka
# Processing Record 8 of Set 3 | taoudenni
# Processing Record 9 of Set 3 | cuamba
# Processing Record 10 of Set 3 | grindavik
# Processing Record 11 of Set 3 | varhaug
# Processing Record 12 of Set 3 | codajas
# Processing Record 13 of Set 3 | dingle
# Processing Record 14 of Set 3 | esil
# Processing Record 15 of Set 3 | talnakh
# Processing Record 16 of Set 3 | deori khas
# Processing Record 17 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 3 | chapais
# Processing Record 19 of Set 3 | marzuq
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | narrabri
# Processing Record 22 of Set 3 | hvolsvollur
# Processing Record 23 of Set 3 | codrington
# Processing Record 24 of Set 3 | saint-joseph
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | bethel
# Processing Record 27 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 3 | nome
# Processing Record 29 of Set 3 | rodrigues alves
# Processing Record 30 of Set 3 | provideniya
# Processing Record 31 of Set 3 | georgetown
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | brae
# Processing Record 34 of Set 3 | hambantota
# Processing Record 35 of Set 3 | panzhihua
# Processing Record 36 of Set 3 | mayo
# Processing Record 37 of Set 3 | ampanihy
# Processing Record 38 of Set 3 | jieshi
# Processing Record 39 of Set 3 | baruun-urt
# Processing Record 40 of Set 3 | esperance
# Processing Record 41 of Set 3 | manaus
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | luhyny
# Processing Record 44 of Set 3 | cidreira
# Processing Record 45 of Set 3 | birjand
# Processing Record 46 of Set 3 | namibe
# Processing Record 47 of Set 3 | hobart
# Processing Record 48 of Set 3 | dmitriyevka
# Processing Record 49 of Set 3 | mount isa
# Processing Record 50 of Set 3 | cortez
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | dunedin
# Processing Record 3 of Set 4 | shihezi
# Processing Record 4 of Set 4 | tasiilaq
# Processing Record 5 of Set 4 | suwannaphum
# Processing Record 6 of Set 4 | east london
# Processing Record 7 of Set 4 | pevek
# Processing Record 8 of Set 4 | boa vista
# Processing Record 9 of Set 4 | alice springs
# Processing Record 10 of Set 4 | pisco
# Processing Record 11 of Set 4 | portland
# Processing Record 12 of Set 4 | suntar
# Processing Record 13 of Set 4 | polyarnyy
# Processing Record 14 of Set 4 | talaya
# Processing Record 15 of Set 4 | jhikargachha
# City not found. Skipping...
# Processing Record 16 of Set 4 | fortuna
# Processing Record 17 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 4 | raudeberg
# Processing Record 19 of Set 4 | anahuac
# Processing Record 20 of Set 4 | thompson
# Processing Record 21 of Set 4 | abbeville
# Processing Record 22 of Set 4 | athabasca
# Processing Record 23 of Set 4 | sombrio
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | nova mayachka
# Processing Record 26 of Set 4 | broome
# Processing Record 27 of Set 4 | lebanon
# Processing Record 28 of Set 4 | manoel urbano
# Processing Record 29 of Set 4 | gravdal
# Processing Record 30 of Set 4 | egvekinot
# Processing Record 31 of Set 4 | platanos
# Processing Record 32 of Set 4 | sawakin
# Processing Record 33 of Set 4 | tashtyp
# Processing Record 34 of Set 4 | lakes entrance
# Processing Record 35 of Set 4 | opobo
# City not found. Skipping...
# Processing Record 36 of Set 4 | maloshuyka
# City not found. Skipping...
# Processing Record 37 of Set 4 | batticaloa
# Processing Record 38 of Set 4 | denia
# Processing Record 39 of Set 4 | najran
# Processing Record 40 of Set 4 | shaunavon
# Processing Record 41 of Set 4 | bergerac
# Processing Record 42 of Set 4 | ilulissat
# Processing Record 43 of Set 4 | nishihara
# Processing Record 44 of Set 4 | port hardy
# Processing Record 45 of Set 4 | laguna
# Processing Record 46 of Set 4 | butaritari
# Processing Record 47 of Set 4 | opuwo
# Processing Record 48 of Set 4 | makakilo city
# Processing Record 49 of Set 4 | mitchell
# Processing Record 50 of Set 4 | norman wells
# Processing Record 1 of Set 5 | jeremie
# Processing Record 2 of Set 5 | goya
# Processing Record 3 of Set 5 | hare bay
# Processing Record 4 of Set 5 | yandoon
# City not found. Skipping...
# Processing Record 5 of Set 5 | avera
# Processing Record 6 of Set 5 | iralaya
# Processing Record 7 of Set 5 | port hueneme
# Processing Record 8 of Set 5 | talavera
# Processing Record 9 of Set 5 | isangel
# Processing Record 10 of Set 5 | pyapon
# Processing Record 11 of Set 5 | moron
# Processing Record 12 of Set 5 | pampas
# Processing Record 13 of Set 5 | port alfred
# Processing Record 14 of Set 5 | brokopondo
# Processing Record 15 of Set 5 | sigiriya
# Processing Record 16 of Set 5 | hasaki
# Processing Record 17 of Set 5 | gewane
# Processing Record 18 of Set 5 | babu
# Processing Record 19 of Set 5 | nhulunbuy
# Processing Record 20 of Set 5 | pimentel
# Processing Record 21 of Set 5 | qandahar
# City not found. Skipping...
# Processing Record 22 of Set 5 | baglung
# Processing Record 23 of Set 5 | fereydun kenar
# Processing Record 24 of Set 5 | tiksi
# Processing Record 25 of Set 5 | husavik
# Processing Record 26 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 5 | bad doberan
# Processing Record 28 of Set 5 | lavrentiya
# Processing Record 29 of Set 5 | kalemie
# Processing Record 30 of Set 5 | brouch
# Processing Record 31 of Set 5 | itahari
# City not found. Skipping...
# Processing Record 32 of Set 5 | port shepstone
# Processing Record 33 of Set 5 | naze
# Processing Record 34 of Set 5 | zaraza
# Processing Record 35 of Set 5 | padang
# Processing Record 36 of Set 5 | quatre cocos
# Processing Record 37 of Set 5 | oshakati
# Processing Record 38 of Set 5 | gat
# Processing Record 39 of Set 5 | kattivakkam
# Processing Record 40 of Set 5 | muisne
# Processing Record 41 of Set 5 | fermoy
# Processing Record 42 of Set 5 | shawville
# Processing Record 43 of Set 5 | chuy
# Processing Record 44 of Set 5 | guerrero negro
# Processing Record 45 of Set 5 | singarayakonda
# Processing Record 46 of Set 5 | adelanto
# Processing Record 47 of Set 5 | salinopolis
# Processing Record 48 of Set 5 | morgan city
# Processing Record 49 of Set 5 | manacapuru
# Processing Record 50 of Set 5 | pangnirtung
# Processing Record 1 of Set 6 | sanchor
# Processing Record 2 of Set 6 | narsaq
# Processing Record 3 of Set 6 | katokhi
# City not found. Skipping...
# Processing Record 4 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 6 | denpasar
# Processing Record 6 of Set 6 | chkalovskoye
# Processing Record 7 of Set 6 | mareeba
# Processing Record 8 of Set 6 | kaitangata
# Processing Record 9 of Set 6 | victoria
# Processing Record 10 of Set 6 | adolfo lopez mateos
# Processing Record 11 of Set 6 | santana
# Processing Record 12 of Set 6 | te anau
# Processing Record 13 of Set 6 | aswan
# Processing Record 14 of Set 6 | sudak
# Processing Record 15 of Set 6 | rosetta
# Processing Record 16 of Set 6 | kapra
# Processing Record 17 of Set 6 | kapit
# Processing Record 18 of Set 6 | hofn
# Processing Record 19 of Set 6 | buala
# Processing Record 20 of Set 6 | san carlos de bariloche
# Processing Record 21 of Set 6 | lebu
# Processing Record 22 of Set 6 | port moresby
# Processing Record 23 of Set 6 | chinsali
# Processing Record 24 of Set 6 | zyryanka
# Processing Record 25 of Set 6 | solnechnyy
# Processing Record 26 of Set 6 | tierranueva
# Processing Record 27 of Set 6 | jaroslaw
# Processing Record 28 of Set 6 | katsuura
# Processing Record 29 of Set 6 | manado
# Processing Record 30 of Set 6 | bac lieu
# Processing Record 31 of Set 6 | college
# Processing Record 32 of Set 6 | sistranda
# Processing Record 33 of Set 6 | bambanglipuro
# Processing Record 34 of Set 6 | los llanos de aridane
# Processing Record 35 of Set 6 | areosa
# Processing Record 36 of Set 6 | yamada
# Processing Record 37 of Set 6 | outjo
# Processing Record 38 of Set 6 | airai
# Processing Record 39 of Set 6 | touros
# Processing Record 40 of Set 6 | kothi
# Processing Record 41 of Set 6 | severodvinsk
# Processing Record 42 of Set 6 | yongan
# Processing Record 43 of Set 6 | ahuimanu
# Processing Record 44 of Set 6 | bilibino
# Processing Record 45 of Set 6 | cherskiy
# Processing Record 46 of Set 6 | asfi
# Processing Record 47 of Set 6 | bodden town
# Processing Record 48 of Set 6 | palmares do sul
# Processing Record 49 of Set 6 | pinawa
# Processing Record 50 of Set 6 | ekhabi
# Processing Record 1 of Set 7 | blackwater
# Processing Record 2 of Set 7 | mormugao
# Processing Record 3 of Set 7 | la ronge
# Processing Record 4 of Set 7 | cheney
# Processing Record 5 of Set 7 | sao domingos
# Processing Record 6 of Set 7 | cabo san lucas
# Processing Record 7 of Set 7 | wanning
# Processing Record 8 of Set 7 | bull savanna
# Processing Record 9 of Set 7 | salmas
# Processing Record 10 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 7 | esso
# Processing Record 12 of Set 7 | banda aceh
# Processing Record 13 of Set 7 | tiarei
# Processing Record 14 of Set 7 | ixtapa
# Processing Record 15 of Set 7 | genhe
# Processing Record 16 of Set 7 | lata
# Processing Record 17 of Set 7 | belyy yar
# Processing Record 18 of Set 7 | taitung
# Processing Record 19 of Set 7 | atlantic city
# Processing Record 20 of Set 7 | dikson
# Processing Record 21 of Set 7 | tura
# Processing Record 22 of Set 7 | manicore
# Processing Record 23 of Set 7 | kodiak
# Processing Record 24 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 7 | korla
# Processing Record 26 of Set 7 | cap malheureux
# Processing Record 27 of Set 7 | mount gambier
# Processing Record 28 of Set 7 | saurimo
# Processing Record 29 of Set 7 | alofi
# Processing Record 30 of Set 7 | derzhavinsk
# Processing Record 31 of Set 7 | imeni poliny osipenko
# Processing Record 32 of Set 7 | pouebo
# Processing Record 33 of Set 7 | tocopilla
# Processing Record 34 of Set 7 | vila
# Processing Record 35 of Set 7 | itoman
# Processing Record 36 of Set 7 | paris
# Processing Record 37 of Set 7 | tatawin
# Processing Record 38 of Set 7 | lebyazhye
# Processing Record 39 of Set 7 | lagoa
# Processing Record 40 of Set 7 | moindou
# Processing Record 41 of Set 7 | asosa
# Processing Record 42 of Set 7 | preobrazheniye
# Processing Record 43 of Set 7 | sakaiminato
# Processing Record 44 of Set 7 | saint-francois
# Processing Record 45 of Set 7 | andenes
# Processing Record 46 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 7 | rosa zarate
# Processing Record 48 of Set 7 | bolshaya glushitsa
# Processing Record 49 of Set 7 | sterling heights
# Processing Record 50 of Set 7 | fort nelson
# Processing Record 1 of Set 8 | kyaikto
# Processing Record 2 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 3 of Set 8 | joshimath
# Processing Record 4 of Set 8 | vanavara
# Processing Record 5 of Set 8 | fairbanks
# Processing Record 6 of Set 8 | baoqing
# Processing Record 7 of Set 8 | suluq
# Processing Record 8 of Set 8 | chatan
# Processing Record 9 of Set 8 | carnarvon
# Processing Record 10 of Set 8 | selma
# Processing Record 11 of Set 8 | komsomolskiy
# Processing Record 12 of Set 8 | lahij
# Processing Record 13 of Set 8 | ostrovnoy
# Processing Record 14 of Set 8 | la uribe
# City not found. Skipping...
# Processing Record 15 of Set 8 | chifeng
# Processing Record 16 of Set 8 | carauari
# Processing Record 17 of Set 8 | henties bay
# Processing Record 18 of Set 8 | miles city
# Processing Record 19 of Set 8 | filingue
# Processing Record 20 of Set 8 | vostok
# Processing Record 21 of Set 8 | ostrow wielkopolski
# Processing Record 22 of Set 8 | tuensang
# Processing Record 23 of Set 8 | port macquarie
# Processing Record 24 of Set 8 | rio grande
# Processing Record 25 of Set 8 | vestmannaeyjar
# Processing Record 26 of Set 8 | qaqortoq
# Processing Record 27 of Set 8 | penzance
# Processing Record 28 of Set 8 | zhuanghe
# Processing Record 29 of Set 8 | klaksvik
# Processing Record 30 of Set 8 | aitape
# Processing Record 31 of Set 8 | viedma
# Processing Record 32 of Set 8 | canakkale
# Processing Record 33 of Set 8 | saint-leu
# Processing Record 34 of Set 8 | guiratinga
# Processing Record 35 of Set 8 | auki
# Processing Record 36 of Set 8 | kulhudhuffushi
# Processing Record 37 of Set 8 | north platte
# Processing Record 38 of Set 8 | yaan
# Processing Record 39 of Set 8 | port keats
# Processing Record 40 of Set 8 | murfreesboro
# Processing Record 41 of Set 8 | robe
# Processing Record 42 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 8 | hualmay
# Processing Record 44 of Set 8 | americus
# Processing Record 45 of Set 8 | arraial do cabo
# Processing Record 46 of Set 8 | iqaluit
# Processing Record 47 of Set 8 | grande riviere du nord
# Processing Record 48 of Set 8 | hami
# Processing Record 49 of Set 8 | ahipara
# Processing Record 50 of Set 8 | iacu
# Processing Record 1 of Set 9 | kasongo-lunda
# Processing Record 2 of Set 9 | plaster rock
# Processing Record 3 of Set 9 | augusto correa
# Processing Record 4 of Set 9 | estelle
# Processing Record 5 of Set 9 | natal
# Processing Record 6 of Set 9 | salalah
# Processing Record 7 of Set 9 | ulladulla
# Processing Record 8 of Set 9 | shubarshi
# Processing Record 9 of Set 9 | kautokeino
# Processing Record 10 of Set 9 | pont-rouge
# Processing Record 11 of Set 9 | ambulu
# Processing Record 12 of Set 9 | sao joao da barra
# Processing Record 13 of Set 9 | jizan
# Processing Record 14 of Set 9 | bossangoa
# Processing Record 15 of Set 9 | san quintin
# Processing Record 16 of Set 9 | otanche
# Processing Record 17 of Set 9 | santa cruz
# Processing Record 18 of Set 9 | krasnoselkup
# Processing Record 19 of Set 9 | mantua
# Processing Record 20 of Set 9 | noshiro
# Processing Record 21 of Set 9 | mezen
# Processing Record 22 of Set 9 | boguchany
# Processing Record 23 of Set 9 | ucluelet
# Processing Record 24 of Set 9 | aklavik
# Processing Record 25 of Set 9 | guilin
# Processing Record 26 of Set 9 | manokwari
# Processing Record 27 of Set 9 | iroquois falls
# Processing Record 28 of Set 9 | pacific grove
# Processing Record 29 of Set 9 | waounde
# Processing Record 30 of Set 9 | olafsvik
# Processing Record 31 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 9 | tual
# Processing Record 33 of Set 9 | qui nhon
# Processing Record 34 of Set 9 | half moon bay
# Processing Record 35 of Set 9 | asau
# Processing Record 36 of Set 9 | langarud
# Processing Record 37 of Set 9 | port-gentil
# Processing Record 38 of Set 9 | guarda
# Processing Record 39 of Set 9 | tupik
# Processing Record 40 of Set 9 | yulara
# Processing Record 41 of Set 9 | san patricio
# Processing Record 42 of Set 9 | funtua
# Processing Record 43 of Set 9 | ilyich
# Processing Record 44 of Set 9 | vila franca do campo
# Processing Record 45 of Set 9 | svobodnyy
# Processing Record 46 of Set 9 | chivay
# Processing Record 47 of Set 9 | ocampo
# Processing Record 48 of Set 9 | lifford
# Processing Record 49 of Set 9 | chimbote
# Processing Record 50 of Set 9 | salym
# Processing Record 1 of Set 10 | sinegorskiy
# Processing Record 2 of Set 10 | barletta
# Processing Record 3 of Set 10 | puerto narino
# Processing Record 4 of Set 10 | kamenka
# Processing Record 5 of Set 10 | san cristobal
# Processing Record 6 of Set 10 | shar
# Processing Record 7 of Set 10 | pathein
# Processing Record 8 of Set 10 | lensk
# Processing Record 9 of Set 10 | tillabery
# City not found. Skipping...
# Processing Record 10 of Set 10 | the pas
# Processing Record 11 of Set 10 | visaginas
# Processing Record 12 of Set 10 | richards bay
# Processing Record 13 of Set 10 | kalmunai
# Processing Record 14 of Set 10 | rio gallegos
# Processing Record 15 of Set 10 | aksarka
# Processing Record 16 of Set 10 | finschhafen
# Processing Record 17 of Set 10 | rocha
# Processing Record 18 of Set 10 | brandon
# Processing Record 19 of Set 10 | hanmer springs
# Processing Record 20 of Set 10 | abnub
# Processing Record 21 of Set 10 | ranchi
# Processing Record 22 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 10 | thyboron
# Processing Record 24 of Set 10 | kargasok
# Processing Record 25 of Set 10 | dzhebariki-khaya
# Processing Record 26 of Set 10 | dongsheng
# Processing Record 27 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 10 | lagos
# Processing Record 29 of Set 10 | sao felix do xingu
# Processing Record 30 of Set 10 | horn lake
# Processing Record 31 of Set 10 | porto novo
# Processing Record 32 of Set 10 | kirakira
# Processing Record 33 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 34 of Set 10 | akonolinga
# Processing Record 35 of Set 10 | gainesville
# Processing Record 36 of Set 10 | avesta
# Processing Record 37 of Set 10 | berlevag
# Processing Record 38 of Set 10 | virginia beach
# Processing Record 39 of Set 10 | chumikan
# Processing Record 40 of Set 10 | urengoy
# Processing Record 41 of Set 10 | vao
# Processing Record 42 of Set 10 | vila velha
# Processing Record 43 of Set 10 | goteborg
# City not found. Skipping...
# Processing Record 44 of Set 10 | linxia
# Processing Record 45 of Set 10 | abu samrah
# Processing Record 46 of Set 10 | rudbar
# Processing Record 47 of Set 10 | syracuse
# Processing Record 48 of Set 10 | monzon
# Processing Record 49 of Set 10 | magistralnyy
# Processing Record 50 of Set 10 | goderich
# Processing Record 1 of Set 11 | beloha
# Processing Record 2 of Set 11 | palauig
# Processing Record 3 of Set 11 | lashio
# Processing Record 4 of Set 11 | celestun
# Processing Record 5 of Set 11 | nara
# Processing Record 6 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 7 of Set 11 | sola
# Processing Record 8 of Set 11 | vynohradivka
# Processing Record 9 of Set 11 | ostersund
# Processing Record 10 of Set 11 | teisani
# Processing Record 11 of Set 11 | laurel
# Processing Record 12 of Set 11 | sayyan
# Processing Record 13 of Set 11 | pangoa
# Processing Record 14 of Set 11 | avon park
# Processing Record 15 of Set 11 | rapid valley
# Processing Record 16 of Set 11 | olinda
# Processing Record 17 of Set 11 | sorong
# Processing Record 18 of Set 11 | udachnyy
# Processing Record 19 of Set 11 | zdvinsk
# Processing Record 20 of Set 11 | bengkulu
# Processing Record 21 of Set 11 | lima
# Processing Record 22 of Set 11 | porangatu
# Processing Record 23 of Set 11 | huesca
# Processing Record 24 of Set 11 | victoria point
# Processing Record 25 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 11 | champerico
# Processing Record 27 of Set 11 | lao cai
# Processing Record 28 of Set 11 | srandakan
# Processing Record 29 of Set 11 | muros
# Processing Record 30 of Set 11 | seybaplaya
# Processing Record 31 of Set 11 | leningradskiy
# Processing Record 32 of Set 11 | maniitsoq
# Processing Record 33 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 34 of Set 11 | gejiu
# Processing Record 35 of Set 11 | xiaolingwei
# Processing Record 36 of Set 11 | nyurba
# Processing Record 37 of Set 11 | wajir
# Processing Record 38 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 39 of Set 11 | margate
# Processing Record 40 of Set 11 | kijaba
# City not found. Skipping...
# Processing Record 41 of Set 11 | sivas
# Processing Record 42 of Set 11 | dudinka
# Processing Record 43 of Set 11 | villa carlos paz
# Processing Record 44 of Set 11 | petropavlovka
# Processing Record 45 of Set 11 | le port
# Processing Record 46 of Set 11 | shingu
# Processing Record 47 of Set 11 | contai
# Processing Record 48 of Set 11 | mkuranga
# Processing Record 49 of Set 11 | great falls
# Processing Record 50 of Set 11 | northam
# Processing Record 1 of Set 12 | coihaique
# Processing Record 2 of Set 12 | roald
# Processing Record 3 of Set 12 | gondanglegi
# Processing Record 4 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 5 of Set 12 | las palmas
# Processing Record 6 of Set 12 | meulaboh
# Processing Record 7 of Set 12 | cranbrook
# Processing Record 8 of Set 12 | cartagena
# Processing Record 9 of Set 12 | richland
# Processing Record 10 of Set 12 | necochea
# Processing Record 11 of Set 12 | matadi
# Processing Record 12 of Set 12 | kununurra
# Processing Record 13 of Set 12 | minbu
# Processing Record 14 of Set 12 | svetlogorsk
# Processing Record 15 of Set 12 | srednekolymsk
# Processing Record 16 of Set 12 | almaznyy
# Processing Record 17 of Set 12 | chara
# Processing Record 18 of Set 12 | oussouye
# Processing Record 19 of Set 12 | guarapari
# Processing Record 20 of Set 12 | kaeo
# Processing Record 21 of Set 12 | diamantino
# Processing Record 22 of Set 12 | rawson
# Processing Record 23 of Set 12 | woodmere
# Processing Record 24 of Set 12 | ribas do rio pardo
# Processing Record 25 of Set 12 | sorland
# Processing Record 26 of Set 12 | saint-augustin
# Processing Record 27 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 12 | lasa
# Processing Record 29 of Set 12 | wilmington
# Processing Record 30 of Set 12 | coos bay
# Processing Record 31 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 12 | anito
# Processing Record 33 of Set 12 | mamlyutka
# Processing Record 34 of Set 12 | broken hill
# Processing Record 35 of Set 12 | tahta
# Processing Record 36 of Set 12 | leh
# Processing Record 37 of Set 12 | phan thiet
# Processing Record 38 of Set 12 | erenhot
# Processing Record 39 of Set 12 | walvis bay
# Processing Record 40 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 12 | zhengjiatun
# Processing Record 42 of Set 12 | malakal
# Processing Record 43 of Set 12 | morehead
# Processing Record 44 of Set 12 | ketchikan
# Processing Record 45 of Set 12 | qiryat shemona
# Processing Record 46 of Set 12 | digras
# Processing Record 47 of Set 12 | muzhi
# Processing Record 48 of Set 12 | lorengau
# Processing Record 49 of Set 12 | tignere
# Processing Record 50 of Set 12 | loukhi
# Processing Record 1 of Set 13 | macae
# Processing Record 2 of Set 13 | kualakapuas
# Processing Record 3 of Set 13 | kahului
# Processing Record 4 of Set 13 | poplar bluff
# Processing Record 5 of Set 13 | lichinga
# Processing Record 6 of Set 13 | saint-quentin
# Processing Record 7 of Set 13 | barnala
# Processing Record 8 of Set 13 | flinders
# Processing Record 9 of Set 13 | ustyuzhna
# Processing Record 10 of Set 13 | paamiut
# Processing Record 11 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 12 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 13 | emba
# Processing Record 14 of Set 13 | bontang
# Processing Record 15 of Set 13 | prado
# Processing Record 16 of Set 13 | tubuala
# Processing Record 17 of Set 13 | arkhangelsk
# Processing Record 18 of Set 13 | cairns
# Processing Record 19 of Set 13 | mouila
# Processing Record 20 of Set 13 | jijiga
# Processing Record 21 of Set 13 | podosinovets
# Processing Record 22 of Set 13 | fairhope
# Processing Record 23 of Set 13 | adrar
# Processing Record 24 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 13 | severobaykalsk
# Processing Record 26 of Set 13 | barabai
# Processing Record 27 of Set 13 | dali
# Processing Record 28 of Set 13 | san buenaventura
# Processing Record 29 of Set 13 | itarema
# Processing Record 30 of Set 13 | tabursuq
# Processing Record 31 of Set 13 | ponca city
# Processing Record 32 of Set 13 | tokmak
# Processing Record 33 of Set 13 | evensk
# Processing Record 34 of Set 13 | moose factory
# Processing Record 35 of Set 13 | antalaha
# Processing Record 36 of Set 13 | beyneu
# Processing Record 37 of Set 13 | peniche
# Processing Record 38 of Set 13 | saint-paul
# Processing Record 39 of Set 13 | raga
# Processing Record 40 of Set 13 | umm kaddadah
# Processing Record 41 of Set 13 | boditi
# Processing Record 42 of Set 13 | likasi
# Processing Record 43 of Set 13 | chebsara
# Processing Record 44 of Set 13 | shubarkuduk
# Processing Record 45 of Set 13 | rock springs
# Processing Record 46 of Set 13 | chunskiy
# Processing Record 47 of Set 13 | cabra
# Processing Record 48 of Set 13 | ginda
# Processing Record 49 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 13 | konyshevka
# Processing Record 1 of Set 14 | santiago
# Processing Record 2 of Set 14 | tazovskiy
# Processing Record 3 of Set 14 | ondangwa
# Processing Record 4 of Set 14 | rajshahi
# Processing Record 5 of Set 14 | dalvik
# Processing Record 6 of Set 14 | cayenne
# Processing Record 7 of Set 14 | zhigansk
# Processing Record 8 of Set 14 | ambunti
# Processing Record 9 of Set 14 | itacoatiara
# Processing Record 10 of Set 14 | letterkenny
# Processing Record 11 of Set 14 | xining
# Processing Record 12 of Set 14 | agirish
# Processing Record 13 of Set 14 | hay river
# Processing Record 14 of Set 14 | ust-nera
# Processing Record 15 of Set 14 | nantucket
# Processing Record 16 of Set 14 | brawley
# Processing Record 17 of Set 14 | iracoubo
# Processing Record 18 of Set 14 | maxixe
# Processing Record 19 of Set 14 | barmer
# Processing Record 20 of Set 14 | mapiripan
# Processing Record 21 of Set 14 | yakeshi
# Processing Record 22 of Set 14 | praia da vitoria
# Processing Record 23 of Set 14 | ambilobe
# Processing Record 24 of Set 14 | yumen
# Processing Record 25 of Set 14 | moree
# Processing Record 26 of Set 14 | puri
# Processing Record 27 of Set 14 | sao filipe
# Processing Record 28 of Set 14 | port augusta
# Processing Record 29 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 30 of Set 14 | samarai
# Processing Record 31 of Set 14 | clyde river
# Processing Record 32 of Set 14 | jinchang
# Processing Record 33 of Set 14 | forest grove
# Processing Record 34 of Set 14 | humboldt
# Processing Record 35 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 14 | wailuku
# Processing Record 37 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 14 | buraydah
# Processing Record 39 of Set 14 | qingdao
# Processing Record 40 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 41 of Set 14 | jackson
# Processing Record 42 of Set 14 | tiznit
# Processing Record 43 of Set 14 | seguin
# Processing Record 44 of Set 14 | chateaudun
# Processing Record 45 of Set 14 | verkhoyansk
# Processing Record 46 of Set 14 | luganville
# Processing Record 47 of Set 14 | kendari
# Processing Record 48 of Set 14 | xai-xai
# Processing Record 49 of Set 14 | burica
# City not found. Skipping...
# Processing Record 50 of Set 14 | ust-tsilma
# Processing Record 1 of Set 15 | ghatanji
# Processing Record 2 of Set 15 | mao
# Processing Record 3 of Set 15 | sioux lookout
# Processing Record 4 of Set 15 | mosquera
# Processing Record 5 of Set 15 | lompoc
# Processing Record 6 of Set 15 | awjilah
# Processing Record 7 of Set 15 | karasjok
# Processing Record 8 of Set 15 | manjacaze
# Processing Record 9 of Set 15 | zhanakorgan
# Processing Record 10 of Set 15 | nokaneng
# Processing Record 11 of Set 15 | onega
# Processing Record 12 of Set 15 | gryfice
# Processing Record 13 of Set 15 | vetovo
# Processing Record 14 of Set 15 | balvi
# Processing Record 15 of Set 15 | kovdor
# Processing Record 16 of Set 15 | minggang
# Processing Record 17 of Set 15 | rafsanjan
# Processing Record 18 of Set 15 | verkhniye kigi
# Processing Record 19 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 15 | peterhead
# Processing Record 21 of Set 15 | abha
# Processing Record 22 of Set 15 | vestmanna
# Processing Record 23 of Set 15 | merauke
# Processing Record 24 of Set 15 | uyo
# Processing Record 25 of Set 15 | vicente guerrero
# Processing Record 26 of Set 15 | micheweni
# Processing Record 27 of Set 15 | baker city
# Processing Record 28 of Set 15 | excelsior springs
# Processing Record 29 of Set 15 | southbridge
# Processing Record 30 of Set 15 | zhaotong
# Processing Record 31 of Set 15 | kurumkan
# Processing Record 32 of Set 15 | eureka
# Processing Record 33 of Set 15 | san jeronimo
# Processing Record 34 of Set 15 | kangaatsiaq
# Processing Record 35 of Set 15 | acapulco
# Processing Record 36 of Set 15 | businga
# Processing Record 37 of Set 15 | palmas bellas
# Processing Record 38 of Set 15 | shakawe
# Processing Record 39 of Set 15 | hammerfest
# Processing Record 40 of Set 15 | podor
# Processing Record 41 of Set 15 | lingyuan
# Processing Record 42 of Set 15 | druzhba
# Processing Record 43 of Set 15 | gazli
# Processing Record 44 of Set 15 | pontes e lacerda
# Processing Record 45 of Set 15 | victor harbor
# Processing Record 46 of Set 15 | praia
# Processing Record 47 of Set 15 | akyab
# Processing Record 48 of Set 15 | nehe
# Processing Record 49 of Set 15 | amarkantak
# Processing Record 50 of Set 15 | neyshabur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton -33.6500  115.3333     52.07        85          71
# 1  Port Elizabeth -33.9180   25.5701     66.31        81         100
# 2    Saint George  37.1041 -113.5841     42.80        45           0
# 3            Okha  53.5739  142.9478     11.98        92          66
# 4          Amahai  -3.3333  128.9167     79.16        84         100
# 5        Saldanha -33.0117   17.9442     62.65        72         100
# 6    Puerto Ayora  -0.7393  -90.3518     78.76        83          74
# 7    Port Hedland -20.3167  118.5667     73.45        78           0
# 8           Ancud -41.8697  -73.8203     56.89        92         100
# 9    Longyearbyen  78.2186   15.6401     21.04        73          40
#
#    Wind Speed Country                 Date Current Description
# 0       12.71      AU  2022-11-17 17:38:22       broken clouds
# 1        1.99      ZA  2022-11-17 17:37:58     overcast clouds
# 2        0.00      US  2022-11-17 17:38:22           clear sky
# 3        5.37      RU  2022-11-17 17:38:22       broken clouds
# 4        2.28      ID  2022-11-17 17:38:23     overcast clouds
# 5       21.85      ZA  2022-11-17 17:38:23     overcast clouds
# 6        4.00      EC  2022-11-17 17:38:24       broken clouds
# 7       16.11      AU  2022-11-17 17:38:24           clear sky
# 8        7.61      CL  2022-11-17 17:33:53     overcast clouds
# 9        6.91      SJ  2022-11-17 17:38:25    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Lat","Lng", "Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_df = city_data_df[new_column_order]

# Display sample data
city_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton      AU -33.6500  115.3333     52.07        85          71
# 1  Port Elizabeth      ZA -33.9180   25.5701     66.31        81         100
# 2    Saint George      US  37.1041 -113.5841     42.80        45           0
# 3            Okha      RU  53.5739  142.9478     11.98        92          66
# 4          Amahai      ID  -3.3333  128.9167     79.16        84         100
#
#    Wind Speed Current Description
# 0       12.71       broken clouds
# 1        1.99     overcast clouds
# 2        0.00           clear sky
# 3        5.37       broken clouds
# 4        2.28     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_df.to_csv(output_data_file, index_label="City_ID")
